# %% [markdown]
# # Rhumlogng SQLALChemy access
#
# I wanted to see how to use SqlAlchemy on the database in RhumlogNg.
#
# Please note. **You need to take a copy of the database** in case you do something stupid.
#
# Please do something like this...
#
#     cp ~/Documents/dv3a.db  ~/dev/Ham/Db/log.db
#
# ## Map an existing database
#
# Sqlalchemy can 'map' / mirror an existing database - please note the connection string with three '/'
# s means relative path.... 4 '/' would be an absolute path.
#
# With the Db Mirrored - we can then create a Class which maps to a table. In out case there are only a few tables.
#
# ## Rhumlogng Tables
#
# There are 4 tables in the database.
#
#   - prefs
#   - dxlist
#   - data
#   - logbook
#
# ### Prefs
#
# The items you set in the main app seem to be stored here.
#
# ### dxlist
#
# This seems to be a list of the worked Dx, and if the QSO has been confirmed. But it has a field called 'info' which is a formatted string.
#
# ### data
#
# This table appears empty
#
# ### logbook
#
# These are all the QSO's.

# %%
#
# Import the libraries for sqlalchemy
#

from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
from sqlalchemy import select          #Needed for selecting data not mapping the Db

Base = automap_base()

# point the connection string to the database
CONN_STR = 'sqlite:///log.db'
engine = create_engine(CONN_STR)

# reflect the tables
Base.prepare(autoload_with=engine)

# %%
# Now create an Alias to make the code look a little cleaner
# We want to have a look at 2 tables. Logbook and dxlist
Logbook = Base.classes.logbook
Dxlist  = Base.classes.dxlist

session = Session(engine)

# %%
# With the Db mapped - we can now generate our select statement.
# We will start with something simple and easy.

stmt = select(Logbook.callsign,Logbook.band).where(Logbook.callsign != "spongebob")
result = session.execute(stmt)
result.all()[:10]    # Just print the first 10 records
# Out:
# [('JG2RFJ', '10m'),
#  ('IT9RZU', '10m'),
#  ('BG8TFN', '10m'),
#  ('JM1VNJ', '10m'),
#  ('EA4URE', '10m'),
#  ('JF1RYU', '10m'),
#  ('VK3IU', '10m'),
#  ('DL6RAI', '10m'),
#  ('OM8ON', '10m'),
#  ('YB1LUE', '10m')]

# %% [markdown]
# # Lets have a look at the DxList
#
#
# The table looks like this
#
#    CREATE TABLE dxlist(dxcc VarChar, info VarChar, dxccadif integer, PRIMARY KEY(dxcc));
#
# So lets see the Philippines data.

# %%
stmt = select(Dxlist.dxcc,Dxlist.info,Dxlist.dxccadif).where(Dxlist.dxcc == "DU")
result = session.execute(stmt)
result.all()
# Out:
# [('DU', 'L.. .L. WXX ... WXL ... LXX ... XXX .W. ... ...', 375)]

# %% [markdown]
# This data looks vey familiar
#
# ![./DxList.png](./DxList.png)
#
# To to remind myself, what this means
#
#   - W
#     - Worked Not Confirmed
#   - X
#     - Worked Confirmed LOTW&Paper
#   - L
#     - Worked Confirmed LOTW
#
# The order is
#
#    **CW** **DATA** **PHONE**

# %% [markdown]
# ## Improvements ?
#
# To me this is not helpful. As I believe we should have some more tables
#
#     - Mode
#       - CW, DATA, PHONE
#     - Status
#       - NOT WORKED
#       - NOT CONFIRMED
#       - CONFIRMED
#     - Band
#       - 180
#       - 80 etc
#
# I will create the Database tables outside the ORM - and reflecting and mapping may confuse me !!
#
#
# ###  MyDefinitions
#
# ```sql
# DROP TABLE IF EXISTS Band;
# DROP TABLE IF EXISTS Mode;
# DROP TABLE IF EXISTS Status;
# DROP TABLE IF EXISTS BMS;
#
# create table Band (bid Integer, name VarChar, Primary Key (bid DESC));
# create table Mode (mid Integer, name VarChar, Primary Key (mid DESC));
# create table Status (sid Integer, code VarChar, name VarChar, Primary Key (sid DESC));
#
# CREATE TABLE BMS (bid Integer NOT NULL, mid Integer NOT NULL, sid Integer NOT NULL, dxccadif Integer NOT NULL,
#     PRIMARY KEY (bid, mid, sid, dxccadif),
#     FOREIGN KEY (bid)REFERENCES Band (bid)
#     FOREIGN KEY (mid)REFERENCES Mode (mid)
#     FOREIGN KEY (sid)REFERENCES Status (sid)
#     FOREIGN KEY (dxccadif) REFERENCES dxlist(dxccadif)
#     );
#
# insert into Band values (160,"180m");
# insert into Band values (80,"80m");
# insert into Band values (60,"60m");
# insert into Band values (40,"40m");
# insert into Band values (30,"30m");
# insert into Band values (20,"20m");
# insert into Band values (17,"17m");
# insert into Band values (15,"15m");
# insert into Band values (12,"12m");
# insert into Band values (10,"10m");
# insert into Band values (6,"6m");
# insert into Band values (2,"2m");
# insert into Band values (1,"Sat");
#
# insert into Mode values(1,"CW");
# insert into Mode values(2,"DATA");
# insert into Mode values(3,"PHONE");
#
# insert into Status values (0,'N',"NOT WORKED");
# insert into Status values (1,'S',"NOT CONFIRMED");
# insert into Status values (2,'X',"CONFIRMED");
#
# ```
#
# It is best to place these commands into a file say **my_upgrades.sql** then to run an update statement
#
#     sqlite3 log.db < my_upgrades.sql
#
# You can then check this by
#
# ```
# select count(*) from Band;
# select count(*) from Mode;
# select count(*) from Status;
# ```
#
# And you should see
#
#     13
#      3
#      3
#
#
# ## We have Added the tables - now what ??
#
# We need to effectivly create a Matierialize view (sorry IBM DB2/Oracle stuff)....
# We do not want to be making a complex query all the time - instead we want to look up in our BMS (Band Mode Status) table.
#
# In order to do that we need to populate it.

# %%
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
from sqlalchemy import select          #Needed for selecting data not mapping the Db
from sqlalchemy.sql import text        #Needed for clearing BMS
Base = automap_base()

# point the connection string to the database
CONN_STR = 'sqlite:///log.db'
engine = create_engine(CONN_STR)

# reflect the tables
Base.prepare(autoload_with=engine)
# Now create an Alias to make the code look a little cleaner
# We want to have a look at 2 tables. Logbook and dxlist
Logbook = Base.classes.logbook
Dxlist  = Base.classes.dxlist
Band    = Base.classes.Band
Mode    = Base.classes.Mode
Status  = Base.classes.Status
BMS     = Base.classes.BMS
session = Session(engine)

# %% [markdown]
# # Populate BMS
#
# We need to create a Record for each Band/Mode/DX
#
# By default we will assume that all BMS are not worked.

# %%
bs = session.execute(select(Band.bid)).all()
ms = session.execute(select(Mode.mid)).all()
ss = session.execute(select(Status.sid).where(Status.name == "NOT WORKED")).all()
# We now need the DXCC ID's 
dxi = session.execute(select(Dxlist.dxccadif,Dxlist.dxcc)).all()

# %%
# We will create a List of BMS objects - then add using the Session build add.

session.execute(text('DELETE FROM BMS'))
session.commit()
print("BMS was truncated")
ToAdd=[]
for b in bs:
    for m in ms:
        for s in ss:
            for d in dxi:
              ToAdd.append(BMS(bid=b[0],mid=m[0],sid=s[0],dxccadif=d[0]))
print(f"We have {len(ToAdd)} objects to Add.")
session.add_all(ToAdd)
session.commit()
# Out:
# BMS was truncated
# We have 15756 objects to Add.

# %%
# We will now get all the Sent but not Confirmed (Ignoring for the moment) 
# For Band/Mode/DXCC 
# The SQL is this 
#     select  distinct l.dxccadif, m.mid,l.mode,s.sid,s.name , l.lotwqsl, l.band  from logbook l ,Mode m, Status s, Band b  where m.name=l.mode and b.name=l.band and s.code = l.lotwqsl and s.name="NOT CONFIRMED";
stmt = select(Logbook.dxccadif, Logbook.band, Logbook.mode,Status.name,Logbook.lotwqsl, Status.sid, Mode.mid).where(Mode.name == Logbook.mode and Band.name == Logbook.band and Status.code == Logbook.lotqsql and Status.name =="NOT CONFIRMED" )
non_confirmed_result = session.execute(stmt).all()
print(f"We have {len(non_confirmed_result)} Non Confirmed in Total")

#Sqlalchemy does not appear to like the .distinct(fld,fld) clause.... so we 
#will make these records unique using python
#Cast data to a set and then back to a list

unique_non_confirmed = list(set(non_confirmed_result))
print(f"We have {len(unique_non_confirmed)} Unique Non Confirmed records")
# Out:
# We have 10386 Non Confirmed in Total
# We have 1473 Unique Non Confirmed records
# /var/folders/ds/nkj_bsw113d71_zp8k3rt4t80000gn/T/ipykernel_1218/2060111363.py:6: SAWarning: SELECT statement has a cartesian product between FROM element(s) "Mode", "logbook" and FROM element "Status".  Apply join condition(s) between each element to resolve.
#   non_confirmed_result = session.execute(stmt).all()

# %%
unique_non_confirmed
# Out:
# [(293, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (324, '40m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (212, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (227, '20m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (15, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (137, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (499, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (137, '15m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (189, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (327, '10m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (27, '160m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (112, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (225, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (387, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (15, '20m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (176, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (110, '20m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (145, '10m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (339, '80m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (248, '20m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (291, '40m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (110, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (1, '40m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (6, '10m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (269, '15m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (339, '40m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (207, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (223, '15m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (236, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (15, '160m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (503, '20m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (294, '10m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (386, '15m', 'DATA', 'NOT CONFIRMED', 'S', 1, 2),
#  (150, '15m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (162, '10m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (272, '15m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (75, '10m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (150, '20m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (386, '40m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (202, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (108, '15m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (1, '20m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (263, '15m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (146, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (212, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (511, '20m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (110, '20m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (501, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (214, '10m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (336, '10m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (324, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (212, '10m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (499, '15m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (497, '15m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (215, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (130, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (327, '15m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (165, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (145, '160m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (166, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (176, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (130, '15m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (248, '20m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (223, '12m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (130, '20m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (504, '10m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (291, '160m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (291, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (245, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (69, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (375, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (285, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (503, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (75, '20m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (137, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (248, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (248, '40m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (136, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (6, '15m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (130, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (52, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (381, '20m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (230, '40m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (308, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (284, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (281, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (21, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (293, '20m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (499, '20m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (54, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (100, '15m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (227, '10m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (135, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (27, '10m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (239, '20m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (176, '15m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (245, '20m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (288, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (137, '17m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (375, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (291, '40m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (287, '40m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (409, '40m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (248, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (339, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (215, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (192, '20m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (269, '15m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (137, '20m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (69, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (386, '10m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (499, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (108, '20m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (146, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (409, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (503, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (504, '160m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (150, '80m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (110, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (112, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (52, '20m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (202, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (145, '160m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (103, '20m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (318, '40m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (294, '20m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (369, '15m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (170, '10m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (63, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (223, '20m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (248, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (363, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (517, '10m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (103, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (503, '40m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (291, '20m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (390, '10m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (269, '160m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (288, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (202, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (386, '20m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (29, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (6, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (517, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (269, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (122, '10m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (50, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (15, '10m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (137, '10m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (269, '160m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (387, '15m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (275, '40m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (215, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (179, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (256, '40m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (162, '10m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (308, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (502, '20m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (499, '40m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (146, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (236, '160m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (503, '40m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (296, '40m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (281, '10m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (375, '10m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (52, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (275, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (504, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (132, '20m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (110, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (275, '10m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (29, '20m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (221, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (130, '20m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (296, '15m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (400, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (202, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (327, '20m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (159, '10m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (215, '40m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (502, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (503, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (230, '160m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (224, '160m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (288, '15m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (375, '15m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (75, '20m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (150, '20m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (263, '15m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (339, '20m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (287, '20m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (239, '20m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (27, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (212, '20m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (245, '20m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (293, '160m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (453, '10m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (46, '20m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (327, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (291, '160m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (145, '160m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (296, '15m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (230, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (318, '15m', 'DATA', 'CONFIRMED', 'S', 2, 2),
#  (137, '40m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (206, '10m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (60, '40m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (369, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (321, '15m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (339, '30m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (375, '40m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (318, '160m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (275, '15m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (21, '20m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (375, '40m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (6, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (15, '15m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (110, '10m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (35, '20m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (324, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (339, '15m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (520, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (339, '20m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (321, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (227, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (236, '10m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (296, '10m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (176, '20m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (369, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (279, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (390, '15m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (15, '10m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (137, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (288, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (504, '20m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (318, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (269, '160m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (339, '10m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (387, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (291, '10m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (497, '20m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (339, '10m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (386, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (497, '40m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (275, '40m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (106, '20m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (266, '15m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (80, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (207, '20m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (284, '10m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (308, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (145, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (110, '15m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (162, '15m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (245, '15m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (207, '20m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (80, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (160, '20m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (169, '15m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (146, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (501, '20m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (503, '40m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (112, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (223, '10m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (50, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (224, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (520, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (339, '6m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (137, '10m', 'DATA', 'CONFIRMED', 'S', 2, 2),
#  (223, '10m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (275, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (284, '20m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (284, '10m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (209, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (165, '20m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (327, '160m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (221, '15m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (296, '20m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (293, '40m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (146, '10m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (15, '160m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (386, '20m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (503, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (170, '20m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (263, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (345, '20m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (339, '20m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (236, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (54, '160m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (66, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (248, '20m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (176, '20m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (179, '40m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (224, '160m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (130, '15m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (190, '10m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (215, '40m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (108, '10m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (35, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (227, '20m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (108, '10m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (348, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (248, '40m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (285, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (245, '15m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (285, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (281, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (293, '160m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (150, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (453, '10m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (248, '10m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (206, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (120, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (499, '20m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (254, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (209, '20m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (150, '15m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (206, '10m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (100, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (262, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (91, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (321, '15m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (245, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (296, '15m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (269, '20m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (381, '15m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (6, '10m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (288, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (501, '20m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (369, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (170, '160m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (190, '10m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (287, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (70, '10m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (386, '10m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (266, '40m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (163, '10m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (296, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (511, '20m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (108, '15m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (299, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (499, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (236, '10m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (387, '20m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (497, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (515, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (137, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (291, '160m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (501, '20m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (54, '160m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (224, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (499, '10m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (112, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (130, '10m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (207, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (223, '15m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (293, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (287, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (145, '10m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (293, '40m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (499, '40m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (291, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (284, '15m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (15, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (269, '20m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (146, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (318, '20m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (6, '15m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (166, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (221, '20m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (318, '12m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (287, '40m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (511, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (50, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (269, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (517, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (497, '10m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (223, '12m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (145, '160m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (265, '20m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (150, '20m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (291, '160m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (192, '20m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (100, '20m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (212, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (46, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (15, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (497, '40m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (291, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (135, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (339, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (108, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (239, '40m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (0, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (284, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (227, '15m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (1, '10m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (142, '15m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (245, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (176, '20m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (94, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (72, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (54, '20m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (265, '20m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (170, '15m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (248, '15m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (176, '15m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (339, '15m', 'DATA', 'NOT WORKED', 'S', 0, 2),
#  (291, '20m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (224, '10m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (221, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (288, '15m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (299, '20m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (170, '10m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (137, '20m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (54, '160m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (387, '15m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (284, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (503, '160m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (387, '20m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (339, '10m', 'DATA', 'NOT WORKED', 'S', 0, 2),
#  (318, '12m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (230, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (91, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (288, '10m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (150, '10m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (339, '15m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (269, '20m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (6, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (272, '15m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (381, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (379, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (345, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (5, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (29, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (52, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (327, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (137, '160m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (248, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (224, '20m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (239, '15m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (499, '20m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (387, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (230, '20m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (363, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (503, '15m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (497, '20m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (296, '10m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (50, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (318, '10m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (106, '20m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (143, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (144, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (6, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (27, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (223, '12m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (6, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (239, '40m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (291, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (339, '40m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (137, '15m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (135, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (1, '20m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (386, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (248, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (248, '20m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (239, '10m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (504, '160m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (275, '40m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (75, '20m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (227, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (150, '15m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (308, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (137, '20m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (6, '20m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (1, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (387, '20m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (21, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (318, '160m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (135, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (236, '160m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (46, '20m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (386, '20m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (224, '20m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (382, '10m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (249, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (502, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (212, '10m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (170, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (146, '10m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (504, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (52, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (146, '10m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (1, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (318, '20m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (318, '15m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (224, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (145, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (318, '20m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (318, '20m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (275, '20m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (272, '10m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (348, '20m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (339, '80m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (223, '20m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (275, '20m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (54, '12m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (387, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (294, '20m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (145, '15m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (497, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (170, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (239, '20m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (502, '20m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (409, '10m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (504, '10m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (400, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (296, '40m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (248, '40m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (190, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (209, '20m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (256, '40m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (137, '20m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (91, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (308, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (54, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (348, '20m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (230, '10m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (166, '20m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (519, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (170, '20m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (318, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (249, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (150, '80m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (345, '10m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (206, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (263, '15m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (339, '20m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (318, '15m', 'DATA', 'NOT WORKED', 'S', 0, 2),
#  (318, '160m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (80, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (288, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (190, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (162, '15m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (1, '20m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (170, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (137, '20m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (293, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (239, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (386, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (69, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (339, '160m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (291, '20m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (281, '10m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (239, '15m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (321, '10m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (145, '20m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (263, '10m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (116, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (170, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (150, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (4, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (223, '15m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (206, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (159, '10m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (233, '20m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (504, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (239, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (146, '160m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (54, '160m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (236, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (363, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (275, '15m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (387, '10m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (515, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (70, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (269, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (145, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (110, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (224, '160m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (293, '160m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (224, '160m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (137, '17m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (279, '15m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (288, '10m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (375, '160m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (266, '40m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (137, '10m', 'DATA', 'NOT WORKED', 'S', 0, 2),
#  (504, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (519, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (299, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (150, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (266, '15m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (1, '10m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (327, '20m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (504, '20m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (446, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (515, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (263, '20m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (137, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (386, '15m', 'DATA', 'CONFIRMED', 'S', 2, 2),
#  (339, '30m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (324, '15m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (263, '20m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (150, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (145, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (50, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (339, '6m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (279, '10m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (266, '160m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (94, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (15, '20m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (145, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (497, '20m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (279, '10m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (230, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (236, '10m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (262, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (166, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (386, '20m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (165, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (13, '20m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (1, '20m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (54, '12m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (212, '20m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (80, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (339, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (70, '10m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (207, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (266, '40m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (136, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (318, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (70, '10m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (345, '10m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (215, '10m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (1, '10m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (409, '40m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (209, '20m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (507, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (179, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (324, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (382, '10m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (375, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (112, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (166, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (239, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (142, '15m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (387, '20m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (103, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (381, '20m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (263, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (339, '20m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (321, '10m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (285, '20m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (386, '10m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (166, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (189, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (209, '20m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (54, '160m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (146, '20m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (137, '160m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (515, '20m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (91, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (345, '40m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (248, '10m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (224, '10m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (170, '20m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (69, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (363, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (150, '160m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (130, '20m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (15, '160m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (387, '160m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (321, '160m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (160, '20m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (430, '10m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (279, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (269, '160m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (137, '160m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (70, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (269, '10m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (108, '20m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (225, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (339, '40m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (112, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (146, '160m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (269, '10m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (54, '160m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (137, '15m', 'DATA', 'NOT WORKED', 'S', 0, 2),
#  (293, '15m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (221, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (137, '40m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (299, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (499, '20m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (15, '40m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (15, '15m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (223, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (202, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (212, '10m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (266, '15m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (72, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (15, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (54, '20m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (130, '20m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (224, '15m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (375, '10m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (327, '20m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (375, '160m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (517, '10m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (46, '10m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (503, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (212, '15m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (287, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (29, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (254, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (266, '160m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (269, '15m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (209, '20m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (230, '40m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (15, '20m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (257, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (269, '20m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (224, '10m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (503, '160m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (285, '20m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (381, '15m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (324, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (227, '40m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (108, '20m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (279, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (189, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (192, '40m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (312, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (318, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (266, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (339, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (1, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (284, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (52, '15m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (497, '40m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (91, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (106, '20m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (327, '160m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (272, '15m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (324, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (75, '10m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (212, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (345, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (381, '10m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (501, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (503, '10m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (284, '20m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (52, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (100, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (501, '15m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (227, '40m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (387, '160m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (35, '20m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (60, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (212, '40m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (142, '15m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (15, '160m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (224, '20m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (339, '40m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (269, '160m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (327, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (100, '20m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (327, '20m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (269, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (339, '40m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (291, '40m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (269, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (339, '160m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (215, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (176, '10m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (345, '20m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (162, '15m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (284, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (345, '40m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (287, '10m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (15, '40m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (4, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (387, '160m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (266, '10m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (130, '20m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (223, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (318, '12m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (21, '20m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (227, '40m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (35, '20m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (381, '20m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (266, '160m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (293, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (215, '10m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (339, '6m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (120, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (275, '20m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (430, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (348, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (262, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (15, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (137, '160m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (281, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (248, '15m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (176, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (170, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (15, '160m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (52, '20m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (387, '160m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (387, '160m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (504, '10m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (6, '20m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (209, '15m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (227, '10m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (209, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (54, '10m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (145, '15m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (387, '40m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (165, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (499, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (285, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (499, '10m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (130, '10m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (176, '20m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (130, '15m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (324, '40m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (0, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (266, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (245, '20m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (50, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (35, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (256, '10m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (189, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (308, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (275, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (224, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (387, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (503, '15m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (52, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (318, '160m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (52, '15m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (288, '160m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (248, '10m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (66, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (499, '20m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (132, '20m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (520, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (223, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (381, '10m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (137, '17m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (269, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (345, '10m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (215, '40m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (1, '40m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (288, '10m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (296, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (130, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (6, '10m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (327, '10m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (375, '15m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (27, '160m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (507, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (224, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (504, '15m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (225, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (100, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (224, '160m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (296, '20m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (5, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (60, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (511, '20m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (46, '20m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (4, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (137, '10m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (318, '10m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (239, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (215, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (339, '160m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (66, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (230, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (291, '20m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (387, '10m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (170, '15m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (80, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (239, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (159, '10m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (130, '20m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (502, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (363, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (381, '15m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (137, '15m', 'DATA', 'CONFIRMED', 'S', 2, 2),
#  (497, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (293, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (324, '12m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (27, '40m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (298, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (381, '20m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (504, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (409, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (298, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (299, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (103, '20m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (27, '40m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (339, '160m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (143, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (327, '20m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (137, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (291, '40m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (375, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (281, '12m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (170, '10m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (386, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (386, '20m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (166, '20m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (321, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (293, '20m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (387, '160m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (339, '80m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (46, '10m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (13, '20m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (0, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (209, '15m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (27, '15m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (150, '160m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (390, '15m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (287, '20m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (122, '10m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (150, '20m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (110, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (379, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (504, '15m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (160, '20m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (430, '10m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (110, '15m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (400, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (291, '10m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (312, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (279, '15m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (145, '160m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (375, '10m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (288, '15m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (130, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (256, '10m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (6, '20m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (206, '10m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (15, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (504, '15m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (324, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (275, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (227, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (103, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (504, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (110, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (189, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (150, '160m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (103, '20m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (150, '10m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (239, '40m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (236, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (504, '40m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (336, '15m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (318, '15m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (263, '15m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (230, '10m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (215, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (224, '15m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (66, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (230, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (212, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (192, '10m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (275, '15m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (72, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (497, '15m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (192, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (256, '10m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (284, '20m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (221, '15m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (146, '20m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (497, '20m', 'CW', 'CONFIRMED', 'S', 2, 1),
#  (291, '160m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (501, '15m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (230, '160m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (281, '12m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (499, '10m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (214, '10m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (165, '20m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (50, '10m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (336, '10m', 'CW', 'NOT WORKED', 'X', 0, 1),
#  (63, '15m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (137, '10m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (272, '10m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (293, '15m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (15, '160m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (263, '10m', 'CW', 'CONFIRMED', 'X', 2, 1),
#  (137, '15m', 'DATA', 'NOT CONFIRMED', 'S', 1, 2),
#  (60, '40m', 'CW', 'NOT CONFIRMED', 'S', 1, 1),
#  (120, '15m', 'CW', 'NOT WORKED', 'S', 0, 1),
#  (272, '10m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (339, '160m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  (293, '15m', 'CW', 'NOT CONFIRMED', 'X', 1, 1),
#  ...]

# %%
list(set(non_confirmed_result.all()))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 list(set(non_confirmed_result.all()))
#
# AttributeError: 'list' object has no attribute 'all'
